# %% [markdown]
# # 📊 Types of Hypothesis Testing
#
#
# ---
#
# ## 1. Chi-square test
# **Tests What?**
# - Independence / association between **categorical** variables.
# - Goodness-of-fit (observed vs. expected counts).
#
# **When?**
# &gt; “Is gender related to voting preference?”
# &gt; “Does the genotype ratio match 1:2:1?”
#
# **Assumptions**
# - Data = counts.
# - ≥ 80 % of expected counts ≥ 5.
#
# ---
#
# ## 2. ANOVA (Analysis of Variance)
# **Tests What?**
# - Compare **≥ 3 group means** simultaneously.
#
# **When?**
# &gt; “Do four fertilizers differ in average yield?”
#
# **Assumptions**
# - Independence, normality of residuals, homogeneity of variances.
#
# ---
#
# ## 3. Two-tailed tests
# **Test What?**
# - Detect effect in **either direction** (≠).
#
# **Hypothesis form**
# - H₀: μ = μ₀  H₁: μ **≠** μ₀
#
# **Why?**
# - Rejection region split into **both tails** of the distribution.
#
# ---
#
# ## 4. Proportion tests
# **Tests What?**
# - Test one proportion vs. hypothesised value, or compare two proportions.
#
# **When?**
# &gt; “Is this coin fair (p = 0.5)?”
# &gt; “Does the new ad have a higher click-through rate?”
#
# **Assumptions**
# - Binary outcome.
# - np ≥ 10 and n(1-p) ≥ 10.
#
# ---
#
# | Question involves … | Use … |
# |---------------------|-------|
# | Categorical × Categorical | Chi-square |
# | ≥ 3 group means | ANOVA |
# | Mean/ proportion, **direction unknown** | Two-tailed version |
# | One or two proportions | One/Two-sample **z-test for proportions** |
